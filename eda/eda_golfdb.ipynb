# %%
import os
import pandas as pd
import numpy as np
import umap
from scipy.io import loadmat
import matplotlib.pyplot as plt

# %%
x = loadmat('../golfdb_master/data/golfDB.mat')
l = list(x['golfDB'][0])
d = dict()
for idx, k in enumerate(l):
    d["{:3d}".format(idx)] = list(l[idx])
df = pd.DataFrame(d).T
df.columns = ["id","youtube_id","player", "sex", "club","view","slow","events","bbox","split"]
df
# Out:
#             id     youtube_id              player  sex      club  \
#   0      [[0]]  [f1BWA5F87Jc]        [SANDRA GAL]  [f]  [driver]
#   1      [[1]]  [f1BWA5F87Jc]        [SANDRA GAL]  [f]  [driver]
#   2      [[2]]  [tA1iotgtMyc]     [CHRIS DIMARCO]  [m]  [driver]
#   3      [[3]]  [tA1iotgtMyc]     [CHRIS DIMARCO]  [m]  [driver]
#   4      [[4]]  [wDCKLePrwHA]  [BROOKE HENDERSON]  [f]  [driver]
# ...        ...            ...                 ...  ...       ...
# 1395  [[1395]]  [bXqJtcWylfQ]  [ARIYA JUTANUGARN]  [f]    [iron]
# 1396  [[1396]]  [TtxGGIzrqWI]       [KENNY PERRY]  [m]  [driver]
# 1397  [[1397]]  [TtxGGIzrqWI]       [KENNY PERRY]  [m]  [driver]
# 1398  [[1398]]  [TtxGGIzrqWI]       [KENNY PERRY]  [m]  [driver]
# 1399  [[1399]]  [TtxGGIzrqWI]       [KENNY PERRY]  [m]  [driver]
#
#                  view   slow  \
#   0   [down-the-line]  [[0]]
#   1   [down-the-line]  [[1]]
#   2   [down-the-line]  [[0]]
#   3   [down-the-line]  [[1]]
#   4   [down-the-line]  [[0]]
# ...               ...    ...
# 1395  [down-the-line]  [[1]]
# 1396        [face-on]  [[0]]
# 1397        [face-on]  [[1]]
# 1398  [down-the-line]  [[0]]
# 1399  [down-the-line]  [[1]]
#
#                                                  events  \
#   0   [[408, 455, 473, 476, 490, 495, 498, 501, 514,...
#   1   [[814, 854, 917, 931, 988, 1006, 1019, 1030, 1...
#   2   [[521, 659, 678, 683, 692, 696, 698, 701, 715,...
#   3   [[1106, 1190, 1244, 1264, 1300, 1313, 1324, 13...
#   4   [[157, 170, 183, 188, 197, 201, 205, 207, 220,...
# ...                                                 ...
# 1395  [[867, 887, 949, 968, 1001, 1017, 1029, 1039, ...
# 1396  [[121, 394, 407, 414, 427, 431, 435, 437, 452,...
# 1397  [[875, 895, 967, 997, 1045, 1061, 1076, 1084, ...
# 1398  [[2585, 2890, 2904, 2912, 2925, 2929, 2932, 29...
# 1399  [[3165, 3212, 3263, 3291, 3346, 3360, 3373, 33...
#
#                                                    bbox  split
#   0   [[0.09765625000000001, 0.006944444444444444, 0...  [[3]]
#   1   [[0.039062500000000014, 0.0006944444444444445,...  [[3]]
#   2   [[0.165625, 0.0006944444444444445, 0.48359375,...  [[3]]
#   3   [[0.18515625, 0.0006944444444444445, 0.465625,...  [[3]]
#   4   [[0.11015625, 0.0006944444444444445, 0.4984375...  [[3]]
# ...                                                 ...    ...
# 1395  [[0.146875, 0.0006944444444444445, 0.4203125, ...  [[1]]
# 1396  [[0.16796875, 0.0006944444444444445, 0.7171875...  [[3]]
# 1397  [[0.16796875, 0.0006944444444444445, 0.696875,...  [[3]]
# 1398  [[0.17578125, 0.0006944444444444445, 0.4203125...  [[3]]
# 1399  [[0.1359375, 0.0006944444444444445, 0.46640625...  [[3]]
#
# [1400 rows x 10 columns]

# %%
df[df['view'] == 'other']
# Out:
#             id     youtube_id           player  sex      club     view   slow  \
#  13     [[13]]  [ja5jdy8_TKw]   [KYLE STANLEY]  [m]  [driver]  [other]  [[1]]
#  16     [[16]]  [y1b7l5xiMWM]    [VIJAY SINGH]  [m]  [driver]  [other]  [[0]]
#  17     [[17]]  [y1b7l5xiMWM]    [VIJAY SINGH]  [m]  [driver]  [other]  [[0]]
#  18     [[18]]  [y1b7l5xiMWM]    [VIJAY SINGH]  [m]  [driver]  [other]  [[1]]
#  31     [[31]]  [tpv8QUM0G0E]  [PAULA CREAMER]  [f]  [driver]  [other]  [[0]]
# ...        ...            ...              ...  ...       ...      ...    ...
# 1385  [[1385]]  [o0t7xaTpUuY]    [TIGER WOODS]  [m]    [iron]  [other]  [[0]]
# 1386  [[1386]]  [o0t7xaTpUuY]   [RORY MCILROY]  [m]    [iron]  [other]  [[1]]
# 1387  [[1387]]  [o0t7xaTpUuY]    [TIGER WOODS]  [m]    [iron]  [other]  [[1]]
# 1390  [[1390]]  [eAQe_V_afjE]   [BEN CRENSHAW]  [m]  [driver]  [other]  [[0]]
# 1391  [[1391]]  [eAQe_V_afjE]   [BEN CRENSHAW]  [m]  [driver]  [other]  [[1]]
#
#                                                  events  \
#  13   [[424, 501, 555, 570, 609, 624, 636, 645, 702,...
#  16   [[91, 162, 174, 179, 188, 192, 196, 198, 217, ...
#  17   [[839, 914, 925, 929, 938, 943, 947, 949, 967,...
#  18   [[1083, 1159, 1195, 1212, 1247, 1270, 1284, 12...
#  31   [[151, 172, 188, 193, 201, 204, 207, 210, 226,...
# ...                                                 ...
# 1385  [[447, 513, 527, 530, 536, 541, 544, 546, 566,...
# 1386  [[718, 751, 796, 809, 836, 859, 868, 876, 947,...
# 1387  [[707, 747, 801, 812, 839, 858, 868, 877, 950,...
# 1390  [[121, 328, 357, 361, 370, 374, 378, 381, 397,...
# 1391  [[609, 663, 724, 740, 779, 794, 808, 818, 883,...
#
#                                                    bbox  split
#  13   [[0.03828125000000001, 0.0006944444444444445, ...  [[2]]
#  16   [[0.16640625, 0.18055555555555555, 0.3484375, ...  [[2]]
#  17   [[0.159375, 0.11666666666666667, 0.36171875, 0...  [[2]]
#  18   [[0.14453125, 0.1111111111111111, 0.36640625, ...  [[2]]
#  31   [[0.203125, 0.06666666666666667, 0.39609375, 0...  [[3]]
# ...                                                 ...    ...
# 1385  [[0.09296875000000002, 0.0006944444444444445, ...  [[2]]
# 1386  [[0.5703125, 0.0006944444444444445, 0.30625, 0...  [[2]]
# 1387  [[0.08906250000000002, 0.0006944444444444445, ...  [[2]]
# 1390  [[0.10859375, 0.1597222222222222, 0.42890625, ...  [[1]]
# 1391  [[0.1125, 0.16527777777777777, 0.428125, 0.781...  [[1]]
#
# [354 rows x 10 columns]
